# %%
import pandas as pd

df = pd.DataFrame([
    { 'nombre': 'Ana', 'notas': [6.5, 7.0, 5.8] },
    { 'nombre': 'Luis', 'notas': [4.2, 5.1, 6.0] },
    { 'nombre': 'Sofía', 'notas': [3.9, 4.0, 4.5] },
    { 'nombre': 'Carlos', 'notas': [5.2, 6.1, 4.8] },
    { 'nombre': 'María', 'notas': [6.7, 5.9, 6.3] },
    { 'nombre': 'Javier', 'notas': [4.5, 4.8, 5.0] },
    { 'nombre': 'Lucía', 'notas': [5.9, 6.2, 6.0] },
    { 'nombre': 'Pedro', 'notas': [3.8, 4.1, 4.0] },
    { 'nombre': 'Elena', 'notas': [6.0, 5.7, 6.5] },
    { 'nombre': 'Raúl', 'notas': [4.3, 4.9, 5.2] },
    { 'nombre': 'Valeria', 'notas': [5.5, 6.0, 5.8] },
    { 'nombre': 'Miguel', 'notas': [4.0, 4.2, 4.5] },
    { 'nombre': 'Isabel', 'notas': [6.1, 6.3, 6.7] },
    { 'nombre': 'Diego', 'notas': [5.0, 5.2, 5.5] },
    { 'nombre': 'Paula', 'notas': [4.7, 5.1, 5.3] },
    { 'nombre': 'Andrés', 'notas': [3.9, 4.0, 4.2] },
    { 'nombre': 'Sara', 'notas': [6.4, 6.6, 6.8] },
    { 'nombre': 'Fernando', 'notas': [5.3, 5.7, 5.9] },
    { 'nombre': 'Natalia', 'notas': [4.6, 4.8, 5.0] },
    { 'nombre': 'Alberto', 'notas': [5.8, 6.0, 6.2] },
    { 'nombre': 'Rocío', 'notas': [4.1, 4.3, 4.5] },
    { 'nombre': 'Iván', 'notas': [6.2, 6.4, 6.6] },
    { 'nombre': 'Patricia', 'notas': [5.4, 5.6, 5.8] },
    { 'nombre': 'Hugo', 'notas': [4.9, 5.1, 5.3] },
    { 'nombre': 'Carmen', 'notas': [6.0, 6.2, 6.4] },
    { 'nombre': 'Mario', 'notas': [4.4, 4.6, 4.8] },
    { 'nombre': 'Julia', 'notas': [5.7, 5.9, 6.1] },
    { 'nombre': 'Adrián', 'notas': [4.2, 4.4, 4.6] },
    { 'nombre': 'Marta', 'notas': [6.3, 6.5, 6.7] },
    { 'nombre': 'Esteban', 'notas': [5.1, 5.3, 5.5] },
    { 'nombre': 'Clara', 'notas': [4.8, 5.0, 5.2] },
    { 'nombre': 'Gabriel', 'notas': [6.5, 6.7, 6.9] }
])

# Expandir notas en columnas
df = df.join(pd.DataFrame(df.pop("notas").tolist(), columns=["nota1", "nota2", "nota3"]))

# Calcular promedio por estudiante
df["promedio"] = df[["nota1", "nota2", "nota3"]].mean(axis=1).round(2)

# Calcular moda global de notas
todas_las_notas = df[["nota1", "nota2", "nota3"]].stack()
moda = todas_las_notas.mode()

# Ordenar por promedio descendente
df_ordenado = df.sort_values(by="promedio", ascending=False).reset_index(drop=True)

print(" Resultados de los estudiantes (ordenados por promedio):\n")
print(df_ordenado.to_string(index=False))

print("\n Moda de las notas (valor que más se repite):")
print(", ".join(map(str, moda.tolist())))
# Out:
# 📊 Resultados de los estudiantes (ordenados por promedio):
#  nombre  nota1  nota2  nota3  promedio
#  Gabriel    6.5    6.7    6.9      6.70
#  Sara       6.4    6.6    6.8      6.60
#  Marta      6.3    6.5    6.7      6.50
#  Iván       6.2    6.4    6.6      6.40
#  Isabel     6.1    6.3    6.7      6.37
#  Carmen     6.0    6.2    6.4      6.20
#  Alberto    5.8    6.0    6.2      6.00
#  Lucía      5.9    6.2    6.0      6.03
#  María      6.7    5.9    6.3      6.30
#  Julia      5.7    5.9    6.1      5.90
#  Elena      6.0    5.7    6.5      6.07
#  Valeria    5.5    6.0    5.8      5.77
#  Patricia   5.4    5.6    5.8      5.60
#  Fernando   5.3    5.7    5.9      5.63
#  Esteban    5.1    5.3    5.5      5.30
#  Diego      5.0    5.2    5.5      5.23
#  Carlos     5.2    6.1    4.8      5.37
#  Natalia    4.6    4.8    5.0      4.80
#  Hugo       4.9    5.1    5.3      5.10
#  Clara      4.8    5.0    5.2      5.00
#  Paula      4.7    5.1    5.3      5.03
#  Javier     4.5    4.8    5.0      4.77
#  Mario      4.4    4.6    4.8      4.60
#  Raúl       4.3    4.9    5.2      4.80
#  Adrián     4.2    4.4    4.6      4.40
#  Luis       4.2    5.1    6.0      5.10
#  Miguel     4.0    4.2    4.5      4.23
#  Rocío      4.1    4.3    4.5      4.30
#  Andrés     3.9    4.0    4.2      4.03
#  Sofía      3.9    4.0    4.5      4.13
#  Pedro      3.8    4.1    4.0      3.97
#  Ana        6.5    7.0    5.8      6.43
#
#  Moda de las notas (valor que más se repite):
# 6.0
