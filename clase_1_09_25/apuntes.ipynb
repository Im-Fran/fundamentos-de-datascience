# %% [markdown]
# # Datos Estudiantes

# %%
# datos
estudiantes = [
    { 'nombre': 'Ana', 'notas': [6.5, 7.0, 5.8] },
    { 'nombre': 'Luis', 'notas': [4.2, 5.1, 6.0] },
    { 'nombre': 'Sofía', 'notas': [3.9, 4.0, 4.5] },
    { 'nombre': 'Carlos', 'notas': [5.2, 6.1, 4.8] },
    { 'nombre': 'María', 'notas': [6.7, 5.9, 6.3] },
    { 'nombre': 'Javier', 'notas': [4.5, 4.8, 5.0] },
    { 'nombre': 'Lucía', 'notas': [5.9, 6.2, 6.0] },
    { 'nombre': 'Pedro', 'notas': [3.8, 4.1, 4.0] },
    { 'nombre': 'Elena', 'notas': [6.0, 5.7, 6.5] },
    { 'nombre': 'Raúl', 'notas': [4.3, 4.9, 5.2] },
    { 'nombre': 'Valeria', 'notas': [5.5, 6.0, 5.8] },
    { 'nombre': 'Miguel', 'notas': [4.0, 4.2, 4.5] },
    { 'nombre': 'Isabel', 'notas': [6.1, 6.3, 6.7] },
    { 'nombre': 'Diego', 'notas': [5.0, 5.2, 5.5] },
    { 'nombre': 'Paula', 'notas': [4.7, 5.1, 5.3] },
    { 'nombre': 'Andrés', 'notas': [3.9, 4.0, 4.2] },
    { 'nombre': 'Sara', 'notas': [6.4, 6.6, 6.8] },
    { 'nombre': 'Fernando', 'notas': [5.3, 5.7, 5.9] },
    { 'nombre': 'Natalia', 'notas': [4.6, 4.8, 5.0] },
    { 'nombre': 'Alberto', 'notas': [5.8, 6.0, 6.2] },
    { 'nombre': 'Rocío', 'notas': [4.1, 4.3, 4.5] },
    { 'nombre': 'Iván', 'notas': [6.2, 6.4, 6.6] },
    { 'nombre': 'Patricia', 'notas': [5.4, 5.6, 5.8] },
    { 'nombre': 'Hugo', 'notas': [4.9, 5.1, 5.3] },
    { 'nombre': 'Carmen', 'notas': [6.0, 6.2, 6.4] },
    { 'nombre': 'Mario', 'notas': [4.4, 4.6, 4.8] },
    { 'nombre': 'Julia', 'notas': [5.7, 5.9, 6.1] },
    { 'nombre': 'Adrián', 'notas': [4.2, 4.4, 4.6] },
    { 'nombre': 'Marta', 'notas': [6.3, 6.5, 6.7] },
    { 'nombre': 'Esteban', 'notas': [5.1, 5.3, 5.5] },
    { 'nombre': 'Clara', 'notas': [4.8, 5.0, 5.2] },
    { 'nombre': 'Gabriel', 'notas': [6.5, 6.7, 6.9] }
]

# %% [markdown]
# # Apuntes de la Clase
#
# Esta clase se centró en el primer bloque en repasar las librerías de NumPy y Pandas, estos se centran en la manipulación y muestreo de datos.

# %%
import numpy as np

lista_notas = [6.5, 7.0, 5.8, 4.9]
array_notas = np.array(lista_notas)

print(f"El array de notas es: {array_notas}")

notas_finales_np = array_notas + 0.5

print(f"El array de notas con + .5 es: {notas_finales_np}")
# Out:
# El array de notas es: [6.5 7.  5.8 4.9]
# El array de notas con + .5 es: [7.  7.5 6.3 5.4]

# %% [markdown]
# # Pandas

# %%
import pandas as pd

df_alumnos = pd.DataFrame(estudiantes)

# Selecciona una columna
print(df_alumnos['nombre'])

# Guarda las notas en columnas separadas
df_alumnos[['nota_1', 'nota_2', 'nota_3']] = pd.DataFrame(df_alumnos['notas'].to_list(), index=df_alumnos.index)

# Calcula el promedio de notas de cada columna y el promedio general del curso
# Out:
# 0          Ana
# 1         Luis
# 2        Sofía
# 3       Carlos
# 4        María
# 5       Javier
# 6        Lucía
# 7        Pedro
# 8        Elena
# 9         Raúl
# 10     Valeria
# 11      Miguel
# 12      Isabel
# 13       Diego
# 14       Paula
# 15      Andrés
# 16        Sara
# 17    Fernando
# 18     Natalia
# 19     Alberto
# 20       Rocío
# 21        Iván
# 22    Patricia
# 23        Hugo
# 24      Carmen
# 25       Mario
# 26       Julia
# 27      Adrián
# 28       Marta
# 29     Esteban
# 30       Clara
# 31     Gabriel
# Name: nombre, dtype: object
#           nota_1     nota_2     nota_3
# count  32.000000  32.000000  32.000000
# mean    5.184375   5.428125   5.575000
# std     0.905934   0.865926   0.828524
# min     3.800000   4.000000   4.000000
# 25%     4.375000   4.800000   4.950000
# 50%     5.150000   5.450000   5.650000
# 75%     6.000000   6.125000   6.225000
# max     6.700000   7.000000   6.900000

# %% [markdown]
# # Trabajando con archivos CSV

# %%
import pandas as pd

df_csv = pd.read_csv('../datos_de_prueba/Estudiantes.csv')

# Muestra 'nombre', 'nota_1', 'nota_2'
pd.DataFrame(df_csv, columns=['nombre', 'nota_1', 'nota_2', 'nota_3'])


# Selecciona como SQL
df_csv.query('nota_1 > 5 & nota_2 > 5')
# Out:
#       nombre  nota_1  nota_2  nota_3
# 0        Ana     6.5     7.0     5.8
# 3     Carlos     5.2     6.1     4.8
# 4      María     6.7     5.9     6.3
# 6      Lucía     5.9     6.2     6.0
# 8      Elena     6.0     5.7     6.5
# 10   Valeria     5.5     6.0     5.8
# 12    Isabel     6.1     6.3     6.7
# 16      Sara     6.4     6.6     6.8
# 17  Fernando     5.3     5.7     5.9
# 19   Alberto     5.8     6.0     6.2
# 21      Iván     6.2     6.4     6.6
# 22  Patricia     5.4     5.6     5.8
# 24    Carmen     6.0     6.2     6.4
# 26     Julia     5.7     5.9     6.1
# 28     Marta     6.3     6.5     6.7
# 29   Esteban     5.1     5.3     5.5
# 31   Gabriel     6.5     6.7     6.9
